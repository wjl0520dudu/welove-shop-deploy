# %%
from rag.models import RetrievalPlan
from rag.vector_store import MilvusVectorStore
from rag.retriever import Retriever
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from backend.rag.models import RetrievalPlan
#       2 from rag.vector_store import MilvusVectorStore
#       3 from rag.retriever import Retriever
#
# ModuleNotFoundError: No module named 'backend'

# %%
store = MilvusVectorStore(collection_name="my_rag_collection")
r = Retriever(vector_store=store)
output = r.retrieve(RetrievalPlan(query="数据库"))
print(output)
# Out:
# plan=RetrievalPlan(intent='knowledge_qa', query='数据库', search_targets=['knowledge'], category=None, category_id=None, product_id=None, brand=None, budget_min=None, budget_max=None, skin_type=None, season=None, positive_requirements=[], negative_requirements=[], doc_types=[], chunk_types=['text'], top_k=5, search_mode='dense') results=[SearchResult(content='LangChain 提供了统一的 Embedding 接口', metadata=ChunkMetadata(doc_id=2, chunk_id=None, product_id=None, category_id=20, source='langchain.md', title='LangChain Embedding', doc_type='faq', chunk_type='text', page=None, chunk_index=0, total_chunks=0, content_hash='', extra={}), score=0.016393441706895828, dense_score=0.016393441706895828, sparse_score=None, rerank_score=None), SearchResult(content='LangChain 提供了统一的 Embedding 接口', metadata=ChunkMetadata(doc_id=2, chunk_id=None, product_id=None, category_id=20, source='langchain.md', title='LangChain Embedding', doc_type='faq', chunk_type='text', page=None, chunk_index=0, total_chunks=0, content_hash='', extra={}), score=0.016129031777381897, dense_score=0.016129031777381897, sparse_score=None, rerank_score=None), SearchResult(content='LangChain 提供了统一的 Embedding 接口', metadata=ChunkMetadata(doc_id=2, chunk_id=None, product_id=None, category_id=20, source='langchain.md', title='LangChain Embedding', doc_type='faq', chunk_type='text', page=None, chunk_index=0, total_chunks=0, content_hash='', extra={}), score=0.01587301678955555, dense_score=0.01587301678955555, sparse_score=None, rerank_score=None)] sources=[Source(doc_id=2, chunk_id=None, doc='LangChain Embedding', page=None, chunk_index=0, score=0.016393441706895828)] knowledge_context='[资料1] 来源：LangChain Embedding\nLangChain 提供了统一的 Embedding 接口\n\n[资料2] 来源：LangChain Embedding\nLangChain 提供了统一的 Embedding 接口\n\n[资料3] 来源：LangChain Embedding\nLangChain 提供了统一的 Embedding 接口'
